# %%
import numpy as np
import pandas as pd


answer_data = pd.read_csv('jk_answers_without_samples_3_2.csv')
sample_data = pd.read_csv('jk_samples_3_2.csv')
document_data = pd.read_csv('jk_documents_3_2.csv')

# %%
sample_data
# Out:
#     sample_category                                           question  \
# 0               [6]  [지원동기] 우리은행 지원 동기와 입행을 위해 어떠한 준비를 해왔는지에 대하여 구체...
# 1               [6]                                              지원동기
# 2               [6]     귀하가 금호아시아나그룹(1지망지원회사)을 지원하게 된 동기에 대해 서술해 주십시오.
# 3               [6]                                               지원동기
# 4               [6]                                         롯데면세점 지원동기
# ..              ...                                                ...
# 637            [15]  본인이 가장 재미를 느끼고 몰입하여 본 경험이나 주도적인 노력을 통해 긍정적인 변화...
# 638            [15]  제주도민에게 사랑 받는 은행이 되기 위해 제주은행이 해야 할 일은 어떤 사항이 있는...
# 639            [15]  본인이 생각하는 리더십과 오너십의 정의 및 본인의 리더십과 오너십을 발휘한 성공 경...
# 640            [15]  본인이 생각하는 리더십과 오너십의 정의 및 본인의 리더십과 오너십을 발휘한 성공 경...
# 641            [15]      진정한 리더란 무엇이라고 생각하는지 자신의 경험을 토대로 서술해 주시기 바랍니다.
#
#                                                 answer  \
# 0    "망망대해 속 나침반, 우리은행"ICT 기술의 발달과 함께 일어난 4차 산업혁명은 ...
# ...

# %%
sample_data['answer'] = sample_data['answer'].apply(temp)

# %%
def temp(str):
    return str.replace('"', ' ')

def temp2(str):
    return str.replace("'", " ")

# %%
a.replace('"',' ')
# Out:
# ' 안녕하세요 '

# %%
a
# Out:
# '"안녕하세요"'

# %%
sample_data
# Out:
#     sample_category                                           question  \
# 0               [6]  [지원동기] 우리은행 지원 동기와 입행을 위해 어떠한 준비를 해왔는지에 대하여 구체...
# 1               [6]                                              지원동기
# 2               [6]     귀하가 금호아시아나그룹(1지망지원회사)을 지원하게 된 동기에 대해 서술해 주십시오.
# 3               [6]                                               지원동기
# 4               [6]                                         롯데면세점 지원동기
# ..              ...                                                ...
# 637            [15]  본인이 가장 재미를 느끼고 몰입하여 본 경험이나 주도적인 노력을 통해 긍정적인 변화...
# 638            [15]  제주도민에게 사랑 받는 은행이 되기 위해 제주은행이 해야 할 일은 어떤 사항이 있는...
# 639            [15]  본인이 생각하는 리더십과 오너십의 정의 및 본인의 리더십과 오너십을 발휘한 성공 경...
# 640            [15]  본인이 생각하는 리더십과 오너십의 정의 및 본인의 리더십과 오너십을 발휘한 성공 경...
# 641            [15]      진정한 리더란 무엇이라고 생각하는지 자신의 경험을 토대로 서술해 주시기 바랍니다.
#
#                                                 answer  \
# 0     망망대해 속 나침반, 우리은행 ICT 기술의 발달과 함께 일어난 4차 산업혁명은 ...
# ...

# %%
sample_data.to_csv('jk_samples_3_2.csv', index=False)

# %%
answer_data[answer_data.answer.apply(len)==3955]
# Out:
#       doc_id  answer_id question  \
# 8356    2254       8356     자기소개
#
#                                                  answer  \
# 8356  성장과정 및 성격의 장.단점 - ‘공동체를 위해’저는 고등학교 시절 서기를 도맡아오...
#
#                                                 doc_url  \
# 8356  https://www.jobkorea.co.kr/starter/PassAssay/V...
#
#                                                 summary question_category  \
# 8356  동부건설에 입사 후 3년 이내에 조직 문화 개선의 전문가로 거듭날 것입니다. 특히 ...              [17]
#
#       doc_view  doc_score  pro_good_cnt  pro_bad_cnt
# 8356      7948       -1.0             0            0

# %%
sample_data = pd.read_csv('jk_samples_3_2.csv')

# %%
sample_data['slice_answer']=sample_data['slice_answer'].apply(temp)
sample_data['slice_answer']=sample_data['slice_answer'].apply(temp2)

# %%
sample_data
# Out:
#     sample_category                                           question  \
# 0               [6]  [지원동기] 우리은행 지원 동기와 입행을 위해 어떠한 준비를 해왔는지에 대하여 구체...
# 1               [6]                                              지원동기
# 2               [6]     귀하가 금호아시아나그룹(1지망지원회사)을 지원하게 된 동기에 대해 서술해 주십시오.
# 3               [6]                                               지원동기
# 4               [6]                                         롯데면세점 지원동기
# ..              ...                                                ...
# 637            [15]  본인이 가장 재미를 느끼고 몰입하여 본 경험이나 주도적인 노력을 통해 긍정적인 변화...
# 638            [15]  제주도민에게 사랑 받는 은행이 되기 위해 제주은행이 해야 할 일은 어떤 사항이 있는...
# 639            [15]  본인이 생각하는 리더십과 오너십의 정의 및 본인의 리더십과 오너십을 발휘한 성공 경...
# 640            [15]  본인이 생각하는 리더십과 오너십의 정의 및 본인의 리더십과 오너십을 발휘한 성공 경...
# 641            [15]      진정한 리더란 무엇이라고 생각하는지 자신의 경험을 토대로 서술해 주시기 바랍니다.
#
#                                                 answer  \
# 0    "망망대해 속 나침반, 우리은행"ICT 기술의 발달과 함께 일어난 4차 산업혁명은 ...
# ...

# %%
list(document_data.major_large.unique()).sort(key=lambda x:len(x))

# %%
print(test)

# %%
temp_list = list(document_data.major_large.unique())

# %%
temp_list.sort(key=lambda x:len(x), reverse=True)

# %%
temp_list
# Out:
# ['자연/공학/의약계열', '인문/사회계열', '예체능계열', '교육계열', '기타']
